# %% [markdown]
# # <center>CC-151L Artificial Intelligence</center>
# <center>Department of Computer Science</center>
# <center>University of Management and Technology</center>

# %% [markdown]
# **Recitation 1: Basics of Python**

# %% [markdown]
# ### Python
# Python is a high-level, open source and interpreted programming language. It is almost like pseudo-code, allows you to express very powerful ideas in few lines of code. Why Python?
# + Simple and easy to learn
# + Used to build web applications
# + Used with big data frameworks
# + Extensive support libraries
# + Must-know language for AI

# %% [markdown]
# In this recitation, we will discuss
#
# 1.   Data types, operators and built-in functions
# 2.   Data containers (lists, tuple, dictionary and sets)
# 3.   Statements and loops
# 4.   Functions and classes

# %% [markdown]
# i) Take input from user

# %%
name = input("What's your name? ")
print('Hi, ', name)
# Out:
# What's your name? Tahir
# Hi,  Tahir

# %% [markdown]
# #### ii) Data types

# %%
a = 1 # integer
print(type(a))
# Out:
# <class 'int'>

# %%
a = 1.1 # float
print(type(a))
# Out:
# <class 'float'>

# %%
a = "hello" # string using double quotes
print(type(a))
b = 'hello' # string using single quote
print(type(b))
# Out:
# <class 'str'>
# <class 'str'>

# %% [markdown]
# Python is a strongly typed language, variables are bound to specific data types. For example

# %%
value = 10 + "10"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-facf51ccde56> in <module>()
# ----> 1 value = 10 + "10"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
number = input("Please enter any number between 1 and 10: ")
value = 10 + number
print(value)
# Out:
# Please enter any number between 1 and 10: 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-18e054fc4152> in <module>()
#       1 number = input("Please enter any number between 1 and 10: ")
# ----> 2 value = 10 + number
#       3 print(value)
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
number = input("Please enter any number between 1 and 10: ")
value = 10 + int(number)
print(value)
# Out:
# Please enter any number between 1 and 10: 5
# 15

# %% [markdown]
# #### iii) Type conversion
# + int() to convert a string into an integer.
# + float() to convert a string into a float.
# + bool() to convert a string into a boolean value.
# + To check the type of variable use print(type(number))
#
# #### iv) Strings

# %%
course = 'Artificial intelligence'
print(len(course)) # to get the length of string
# Out:
# 13

# %%
combine_s = 'pak'+'istan'
print(combine_s) # combine two strings using + operator
# Out:
# pakistan

# %%
repeat_d = '#'*15 # repeat string multiple times using * operator
print(repeat_d)
# Out:
# ###############

# %%
course = 'Artificial intelligence'  # square brackets used to access the elements of string
print(course[0:4])
# Out:
# Deep

# %%
course = 'Artificial intelligence'
print(course.lower()) # lower() method returns the string in lower case
# Out:
# deep learning

# %%
course = 'Artificial intelligence'
print(course.upper()) # upper() method returns the string in upper case
# Out:
# DEEP LEARNING

# %%
height = 'tall'
print(height.replace('t','m')) # replace() method used to swap elements of string
# Out:
# mall

# %%
splitted = course.split(' ') # split the string into two sub-strings
print(splitted)
# Out:
# ['deep', 'learning']

# %%
check_var = 'deep' in course # check if the phrase is in the string or not
print(check_var)
# Out:
# True

# %%
acc = 90
txt = "testing {}% accuracy"
print(txt.format(acc)) # combine text with numbers
# Out:
# testing 90% accuracy

# %%
acc = 90.845689
txt = "testing accuracy: {:.2f}%"
print(txt.format(acc)) # combine text with numbers with two decimal format
# Out:
# testing accuracy: 90.85%

# %% [markdown]
# v) Common operators in python

# %%
x = 5
y = 2
print("x+y = ",x + y) # addition
print("x-y = ",x-y) # subtraction
print("x*y = ",x * y) # multiplication
print("x/y = ",x / y) # division
print("x%y = ",x % y) # modulus
print("x**y = ",x**y) # power
# Out:
# x+y =  7
# x-y =  3
# x*y =  10
# x/y =  2.5
# x%y =  1
# x**y =  25

# %% [markdown]
# #### vi) Logical operators to combine conditional statements

# %%
x = 5
y = 5
print(x > 3 and x < 10)
print(x < 5 or x < 4)
print(not(x > 3 and x < 10))
# Out:
# True
# False
# False
